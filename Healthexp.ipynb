# %% [markdown]
# <a href="https://colab.research.google.com/github/chirag912/first-project/blob/usecase/Healthexp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("healthexp.csv")

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
df
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
df.tail(10)
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 264  2019         France      5167.839             82.9
# 265  2019  Great Britain      4385.463             81.4
# 266  2019          Japan      4610.794             84.4
# 267  2019            USA     10855.517             78.8
# 268  2020         Canada      5828.324             81.7
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0

# %%
df['Country'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Attributes

# %%
df.dtypes
# Out:
# Year                 int64
# Country             object
# Spending_USD       float64
# Life_Expectancy    float64
# dtype: object

# %%
 df.columns
# Out:
# Index(['Year', 'Country', 'Spending_USD', 'Life_Expectancy'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=274, step=1),
#  Index(['Year', 'Country', 'Spending_USD', 'Life_Expectancy'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 1096

# %%
df.shape
# Out:
# (274, 4)

# %%
df.values
# Out:
# array([[1970, 'Germany', 252.311, 70.6],
#        [1970, 'France', 192.143, 72.2],
#        [1970, 'Great Britain', 123.993, 71.9],
#        ...,
#        [2020, 'Great Britain', 5018.7, 80.4],
#        [2020, 'Japan', 4665.641, 84.7],
#        [2020, 'USA', 11859.179, 77.0]], dtype=object)

# %% [markdown]
# ## Methods

# %%
df.describe()
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   274.000000    274.000000       274.000000
# mean   1996.992701   2789.338905        77.909489
# std      14.180933   2194.939785         3.276263
# min    1970.000000    123.993000        70.600000
# 25%    1985.250000   1038.357000        75.525000
# 50%    1998.000000   2295.578000        78.100000
# 75%    2009.000000   4055.610000        80.575000
# max    2020.000000  11859.179000        84.700000

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
df.tail()
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0

# %%
df. max()
# Out:
# Year                    2020
# Country                  USA
# Spending_USD       11859.179
# Life_Expectancy         84.7
# dtype: object

# %%
df.min()
# Out:
# Year                  1970
# Country             Canada
# Spending_USD       123.993
# Life_Expectancy       70.6
# dtype: object

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]>

# %%
df.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]>

# %%
df.sample(2)
# Out:
#      Year  Country  Spending_USD  Life_Expectancy
# 233  2014  Germany      5151.709             81.2
# 224  2012    Japan      3970.765             83.2

# %%
df.dropna()
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
df.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]>

# %%
df[["Spending_USD"]]
# Out:
#      Spending_USD
# 0         252.311
# 1         192.143
# 2         123.993
# 3         150.437
# 4         326.961
# ..            ...
# 269      6938.983
# 270      5468.418
# 271      5018.700
# 272      4665.641
# 273     11859.179
#
# [274 rows x 1 columns]

# %%
df_spend = df.groupby(['Spending_USD'])

# %%
df_spend

# %%
  df_spend.mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7e9cad1c0be0>>

# %%
df_part = df[df['Spending_USD']>500]

# %%
df_part
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 19   1975        Germany       532.481             71.4
# 22   1975            USA       560.750             72.7
# 23   1976         Canada       543.337             73.8
# 24   1976        Germany       591.098             71.8
# 26   1976            USA       638.851             72.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [246 rows x 4 columns]

# %%
df[['Year', 'Country','Life_Expectancy']]
# Out:
#      Year        Country  Life_Expectancy
# 0    1970        Germany             70.6
# 1    1970         France             72.2
# 2    1970  Great Britain             71.9
# 3    1970          Japan             72.0
# 4    1970            USA             70.9
# ..    ...            ...              ...
# 269  2020        Germany             81.1
# 270  2020         France             82.3
# 271  2020  Great Britain             80.4
# 272  2020          Japan             84.7
# 273  2020            USA             77.0
#
# [274 rows x 3 columns]

# %%
df.iloc[[0]]
# Out:
#    Year  Country  Spending_USD  Life_Expectancy
# 0  1970  Germany       252.311             70.6

# %%
df.iloc[[4]]
# Out:
#    Year Country  Spending_USD  Life_Expectancy
# 4  1970     USA       326.961             70.9

# %%
df.iloc[[-1]]
# Out:
#      Year Country  Spending_USD  Life_Expectancy
# 273  2020     USA     11859.179             77.0

# %%
df.iloc[:,0]
# Out:
# 0      1970
# 1      1970
# 2      1970
# 3      1970
# 4      1970
#        ...
# 269    2020
# 270    2020
# 271    2020
# 272    2020
# 273    2020
# Name: Year, Length: 274, dtype: int64

# %%
 df.iloc[:,-1]
# Out:
# 0      70.6
# 1      72.2
# 2      71.9
# 3      72.0
# 4      70.9
#        ...
# 269    81.1
# 270    82.3
# 271    80.4
# 272    84.7
# 273    77.0
# Name: Life_Expectancy, Length: 274, dtype: float64

# %%
 df.iloc[0:7,:]
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9
# 5  1971         Canada       313.391             72.8
# 6  1971        Germany       298.251             70.8
