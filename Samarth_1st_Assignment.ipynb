# %% [markdown]
# <a href="https://colab.research.google.com/github/chirag912/first-project/blob/main/Samarth_1st_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
univ = pd.read_csv('Universities.csv')

# %%
univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_univ = scaler.fit_transform(univ.iloc[:,1:])

# %%
scaled_univ
# Out:
# array([[ 0.41028362,  0.6575195 , -0.88986682,  0.07026045, -0.33141256,
#          0.82030265],
#        [ 1.39925928,  1.23521235, -0.73465749, -1.68625071,  2.56038138,
#         -0.64452351],
#        [-0.06065717, -0.76045386,  1.02438157, -0.93346022, -0.16712136,
#         -1.65863393],
#        [ 0.41028362, -0.02520842, -0.78639393, -0.18066972,  0.29164871,
#          0.14422904],
#        [ 0.12771914,  0.34241431, -0.32076595,  0.07026045, -0.39084607,
#          0.36958691],
#        [ 0.69284809,  0.6575195 , -0.83813038, -0.68253005,  0.33778044,
#          0.93298158],
#        [ 0.4573777 ,  0.71003703, -0.47597528, -0.18066972,  0.29695528,
#          0.93298158],
#        [-0.10775125, -0.13024348, -0.78639393, -0.18066972, -0.51381683,
#          0.59494478],
#        [ 1.25797704,  0.76255456, -1.30375836, -0.43159988,  0.85874344,
#          1.15833946],
#        [ 0.36318954, -0.07772595,  0.24833493, -1.43532055,  2.21481798,
#          0.0315501 ],
# ...

# %%
univ['Univ'].dtype
# Out:
# dtype('O')

# %%
univ.dtypes
# Out:
# Univ        object
# SAT          int64
# Top10        int64
# Accept       int64
# SFRatio      int64
# Expenses     int64
# GradRate     int64
# dtype: object

# %%
univ.max()
# Out:
# Univ         Yale
# SAT          1415
# Top10         100
# Accept         90
# SFRatio        25
# Expenses    63575
# GradRate       97
# dtype: object

# %%
univ.std()
# Out:
# <ipython-input-16-2a093b5e8935>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   univ.std()
# SAT           108.359771
# Top10          19.433905
# Accept         19.727308
# SFRatio         4.067350
# Expenses    14424.883165
# GradRate        9.057778
# dtype: float64

# %%
univ[['SAT']]
# Out:
#      SAT
# 0   1310
# 1   1415
# 2   1260
# 3   1310
# 4   1280
# 5   1340
# 6   1315
# 7   1255
# 8   1400
# 9   1305
# 10  1380
# 11  1260
# 12  1255
# 13  1081
# 14  1375
# 15  1005
# 16  1360
# 17  1075
# 18  1240
# 19  1290
# 20  1180
# 21  1285
# 22  1225
# 23  1085
# 24  1375

# %%
univ.iloc[[0]]
# Out:
#     Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0  Brown  1310     89      22       13     22704        94

# %%
univ.iloc[:,0]
# Out:
# 0            Brown
# 1          CalTech
# 2              CMU
# 3         Columbia
# 4          Cornell
# 5        Dartmouth
# 6             Duke
# 7       Georgetown
# 8          Harvard
# 9     JohnsHopkins
# 10             MIT
# 11    Northwestern
# 12       NotreDame
# 13       PennState
# 14       Princeton
# 15          Purdue
# 16        Stanford
# 17        TexasA&M
# 18      UCBerkeley
# 19        UChicago
# 20       UMichigan
# 21           UPenn
# 22             UVA
# 23      UWisconsin
# 24            Yale
# Name: Univ, dtype: object

# %%
univ.iloc[:,-1]
# Out:
# 0     94
# 1     81
# 2     72
# 3     88
# 4     90
# 5     95
# 6     95
# 7     92
# 8     97
# 9     87
# 10    91
# 11    89
# 12    94
# 13    80
# 14    95
# 15    69
# 16    93
# 17    67
# 18    78
# 19    87
# 20    85
# 21    90
# 22    92
# 23    71
# 24    96
# Name: GradRate, dtype: int64

# %%
univ.iloc[0:7]
# Out:
#         Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0      Brown  1310     89      22       13     22704        94
# 1    CalTech  1415    100      25        6     63575        81
# 2        CMU  1260     62      59        9     25026        72
# 3   Columbia  1310     76      24       12     31510        88
# 4    Cornell  1280     83      33       13     21864        90
# 5  Dartmouth  1340     89      23       10     32162        95
# 6       Duke  1315     90      30       12     31585        95

# %%
univ.iloc[:,0:2]
# Out:
#             Univ   SAT
# 0          Brown  1310
# 1        CalTech  1415
# 2            CMU  1260
# 3       Columbia  1310
# 4        Cornell  1280
# 5      Dartmouth  1340
# 6           Duke  1315
# 7     Georgetown  1255
# 8        Harvard  1400
# 9   JohnsHopkins  1305
# 10           MIT  1380
# 11  Northwestern  1260
# 12     NotreDame  1255
# 13     PennState  1081
# 14     Princeton  1375
# 15        Purdue  1005
# 16      Stanford  1360
# 17      TexasA&M  1075
# 18    UCBerkeley  1240
# 19      UChicago  1290
# 20     UMichigan  1180
# 21         UPenn  1285
# 22           UVA  1225
# 23    UWisconsin  1085
# 24          Yale  1375

# %%
univ.iloc[:,3:-1]
# Out:
#     Accept  SFRatio  Expenses
# 0       22       13     22704
# 1       25        6     63575
# 2       59        9     25026
# 3       24       12     31510
# 4       33       13     21864
# 5       23       10     32162
# 6       30       12     31585
# 7       24       12     20126
# 8       14       11     39525
# 9       44        7     58691
# 10      30       10     34870
# 11      39       11     28052
# 12      42       13     15122
# 13      54       18     10185
# 14      14        8     30220
# 15      90       19      9066
# 16      20       12     36450
# 17      67       25      8704
# 18      40       17     15140
# 19      50       13     38380
# 20      68       16     15470
# 21      36       11     27553
# 22      44       14     13349
# 23      69       15     11857
# 24      19       11     43514

# %%
univ.iloc[[1,4,8],[0,5]]
# Out:
#       Univ  Expenses
# 1  CalTech     63575
# 4  Cornell     21864
# 8  Harvard     39525

# %%
univ.mean()
# Out:
# <ipython-input-38-c84526551b6c>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   univ.mean()
# SAT          1266.44
# Top10          76.48
# Accept         39.20
# SFRatio        12.72
# Expenses    27388.00
# GradRate       86.72
# dtype: float64

# %%
univ.values
# Out:
# array([['Brown', 1310, 89, 22, 13, 22704, 94],
#        ['CalTech', 1415, 100, 25, 6, 63575, 81],
#        ['CMU', 1260, 62, 59, 9, 25026, 72],
#        ['Columbia', 1310, 76, 24, 12, 31510, 88],
#        ['Cornell', 1280, 83, 33, 13, 21864, 90],
#        ['Dartmouth', 1340, 89, 23, 10, 32162, 95],
#        ['Duke', 1315, 90, 30, 12, 31585, 95],
#        ['Georgetown', 1255, 74, 24, 12, 20126, 92],
#        ['Harvard', 1400, 91, 14, 11, 39525, 97],
#        ['JohnsHopkins', 1305, 75, 44, 7, 58691, 87],
#        ['MIT', 1380, 94, 30, 10, 34870, 91],
#        ['Northwestern', 1260, 85, 39, 11, 28052, 89],
#        ['NotreDame', 1255, 81, 42, 13, 15122, 94],
#        ['PennState', 1081, 38, 54, 18, 10185, 80],
#        ['Princeton', 1375, 91, 14, 8, 30220, 95],
#        ['Purdue', 1005, 28, 90, 19, 9066, 69],
#        ['Stanford', 1360, 90, 20, 12, 36450, 93],
#        ['TexasA&M', 1075, 49, 67, 25, 8704, 67],
#        ['UCBerkeley', 1240, 95, 40, 17, 15140, 78],
# ...

# %%
univ[['SAT', 'GradRate', 'Expenses']].agg(['min','max','mean'])
# Out:
#           SAT  GradRate  Expenses
# min   1005.00     67.00    8704.0
# max   1415.00     97.00   63575.0
# mean  1266.44     86.72   27388.0

# %%
univ.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000
